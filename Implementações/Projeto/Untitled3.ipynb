# %%
import import_ipynb

# %%
import PréProcessamento
# Out:
# importing Jupyter notebook from PréProcessamento.ipynb
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0b3ac54e7389> in <module>
# ----> 1 import PréProcessamento
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/import_ipynb.py in load_module(self, fullname)
#      59                 code = self.shell.input_transformer_manager.transform_cell(cell.source)
#      60                 # run the code in themodule
# ---> 61                 exec(code, mod.__dict__)
# ...
